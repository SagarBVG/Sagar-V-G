# %%
Write a program to print hello python

# %%
s="Hello Python"
print(s)
# Out:
# Hello Python

# %%
Write a program to generate arithmetic operation addition and division

# %%
try:
  a=int(input("Enter a first number: "))
  b=int(input("Enter a second number: "))
  c=a/b
  print("Div:",c)
  d=a+b
  print("Addition:",d)
except:
  print("Enter positive denominator only")
# Out:
# Enter a first number: 10
# Enter a second number: 20
# Div: 0.5
# Addition: 30

# %%
Write a Python program to find the area of a triangle?

# %%
base=float(input("Enter a value of base: "))
height=float(input("Enter a value of height: "))
if base<=0 or height<=0:
  print("Enter positive values only")
else:
  Area_of_triangle=0.5*base*height
  print("Area of triangle is:",Area_of_triangle)
# Out:
# Enter a value of base: 10
# Enter a value of height: 20
# Area of triangle is: 100.0

# %%
Write a Python program to swap two variables?

# %%
a=input("Enter a variable 1: ")
b=input("Enter variable 2: ")
temp=a
a=b
b=temp

print("Value of a after swapping: ",a)
print("Value of b after swapping: ",b)
# Out:
# Enter a variable 1: sagar
# Enter variable 2: gundale
# Value of a after swapping:  gundale
# Value of b after swapping:  sagar

# %%
Write a Python program to generate a random number?

# %%
import random

print(random.randint(0,100))
# Out:
# 45

# %%
import random

print(random.randint(0,100))
# Out:
# 59
